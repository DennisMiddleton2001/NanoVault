# %%
def get_model_path(fq_path, name):
    tag = 'ComfyUI/models/'
    name = "gemma_3_12B_it_fp4_mixed.safetensors"
    start_idx = fq_path.find(tag)+len(tag)
    name_idx = fq_path.find(name)
    path_and_name = fq_path[start_idx:]
    if path_and_name.endswith(name):
        path = path_and_name[:-len(name)-1]
    return path

fq_path = "/home/darth-tedious/.sovereign-ai/ComfyUI/models/loras/gemma_3_12B_it_fp4_mixed.safetensors"
name = "gemma_3_12B_it_fp4_mixed.safetensors"
path = get_model_path(fq_path, name)
print(path)
# Out:
# loras
